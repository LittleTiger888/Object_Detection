# %%
# # Pip install (recommended)

# !pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.7 🚀 Python-3.12.3 torch-2.9.0+cu130 CUDA:0 (NVIDIA GB10, 122570MiB)
# Setup complete ✅ (20 CPUs, 119.7 GB RAM, 515.6/3755.0 GB disk)
# /home/aispark/Project/Object_Detect/.venv/lib/python3.12/site-packages/torch/cuda/__init__.py:283: UserWarning:
#     Found GPU0 NVIDIA GB10 which is of cuda capability 12.1.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (8.0) - (12.0)
#
#   warnings.warn(

# %% [markdown]
# ## Train YOLO v26 Model

# %%
# !python train.py --data data.yaml --weights YOLO26s.pt --batch-size 8 --name Model --img 640 --epochs 150
# !yolo task=segment \
    mode=train \
    model=yolo26s.pt \
    data=data.yaml \
    epochs=50 \
    imgsz=640 \
    batch=5 \
    project= /home/aispark/Project/Object_Detect/YOLO26_TrainingResults \
    name=LicensePlates_YOLO26
# Out:
# WARNING ⚠️ conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# /home/aispark/Project/Object_Detect/.venv/lib/python3.12/site-packages/torch/cuda/__init__.py:283: UserWarning:
#     Found GPU0 NVIDIA GB10 which is of cuda capability 12.1.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (8.0) - (12.0)
#
#   warnings.warn(
# Ultralytics 8.4.7 🚀 Python-3.12.3 torch-2.9.0+cu130 CUDA:0 (NVIDIA GB10, 122570MiB)
# ...

# %% [markdown]
# ## Export to ONNX

# %%
# !yolo mode=export \
    model=/home/aispark/Project/Object_Detect/YOLO26_TrainingResults/LicensePlates_YOLO26/weights/best.pt \
    format=oonx
# Out:
# WARNING ⚠️ Invalid export format='oonx', updating to format='onnx'
# Ultralytics 8.4.7 🚀 Python-3.12.3 torch-2.9.0+cu130 CPU (aarch64)
# YOLO26s summary (fused): 122 layers, 9,465,567 parameters, 0 gradients, 20.5 GFLOPs
#
# PyTorch: starting from '/home/aispark/Project/Object_Detect/YOLO26_TrainingResults/LicensePlates_YOLO26/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (19.4 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxslim>=0.1.71', 'onnxruntime'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/17.4 MB ? eta -:--:--
#    ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/17.4 MB 8.4 MB/s eta 0:00:03
#    ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.7/17.4 MB 10.1 MB/s eta 0:00:02
#    ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/17.4 MB 10.7 MB/s eta 0:00:02
#    ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/17.4 MB 10.9 MB/s eta 0:00:02
# ...
